# %%
import requests

headers = {
   "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
   "Accept-Encoding": "gzip, deflate, br",
   "Accept-Language": "zh-TW,zh;q=0.9",
   "Host": "example.com",  #目標網站
   "Sec-Fetch-Dest": "document",
   "Sec-Fetch-Mode": "navigate",
   "Sec-Fetch-Site": "none",
   "Upgrade-Insecure-Requests": "1",
   "User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36" #使用者代理
}
 
html = requests.get(url="https://example.com", headers=headers)

# %%
from fake_useragent import UserAgent

# %%
def set_header_user_agent():
    user_agent = UserAgent()
    return user_agent.random

# %%
user_agent = set_header_user_agent()
headers = {"User-Agent":user_agent,"referer":"www.google.com"}

url = "https://data.coa.gov.tw/Service/OpenData/TransService.aspx?UnitId=LC7YWlenhLuP"

html = requests.get(url,headers=headers)

# %%
html.json()
# Out:
# [{'CROP_UID': '01003000999000000',
#   'CNAME': '其他景觀作物',
#   'ALIAS_CNAME': '',
#   'PLV1': '010',
#   'PLV1_NAME': '其他作物類',
#   'PLV2': '03',
#   'PLV2_NAME': '景觀類',
#   'PLV5': '000',
#   'PLV5_NAME': '',
#   'PLV3': '999',
#   'PLV3_NAME': '其他景觀作物',
#   'PLV4': '0000',
#   'PLV4_NAME': '',
#   'PLV6': '00'},
#  {'CROP_UID': '01003118004000000',
#   'CNAME': '景觀小油菊 ',
#   'ALIAS_CNAME': '',
#   'PLV1': '010',
#   'PLV1_NAME': '其他作物類',
#   'PLV2': '03',
#   'PLV2_NAME': '景觀類',
#   'PLV5': '118',
#   'PLV5_NAME': '菊科',
#   'PLV3': '004',
#   'PLV3_NAME': '景觀小油菊 ',
#   'PLV4': '0000',
#   'PLV4_NAME': '',
#   'PLV6': '00'},
#  {'CROP_UID': '01003118003000000',
#   'CNAME': '景觀萬壽菊 ',
#   'ALIAS_CNAME': '臭菊、臭芙蓉、金菊、黃菊、西番菊、千壽菊、花面菊、蜂窩菊、 金花菊、金雞菊 ',
#   'PLV1': '010',
#   'PLV1_NAME': '其他作物類',
#   'PLV2': '03',
#   'PLV2_NAME': '景觀類',
#   'PLV5': '118',
#   'PLV5_NAME': '菊科',
#   'PLV3': '003',
#   'PLV3_NAME': '景觀萬壽菊 ',
#   'PLV4': '0000',
#   'PLV4_NAME': '',
#   'PLV6': '00'},
# ...

# %%
print(headers)
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; ko-KR) AppleWebKit/533.20.25 (KHTML, like Gecko) Version/5.0.4 Safari/533.20.27'}

# %%
import time
import random

sleep_time = random.uniform(3, 5)
time.sleep(sleep_time)
